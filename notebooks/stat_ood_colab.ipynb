# %% [markdown]
# # Stat-OOD: VS Code + Colab Extension
#
# **실행 순서:**
# 1. GPU 확인
# 2. 프로젝트 설정
# 3. 실험 실행

# %% [markdown]
# ## 1. Verify GPU

# %%
# !nvidia-smi
# Out:
# Mon Jan 12 07:18:17 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA: {torch.cuda.is_available()} - {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'N/A'}")
# Out:
# PyTorch: 2.9.0+cu126
# CUDA: True - Tesla T4

# %% [markdown]
# ## 2. Setup Project

# %%
# !pip install -q uv
# !rm -rf /content/stat-ood
# !git clone https://github.com/sucpark/stat-ood.git /content/stat-ood
# %cd /content/stat-ood
# !uv sync
# Out:
# Cloning into '/content/stat-ood'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 163 (delta 77), reused 138 (delta 52), pack-reused 0 (from 0)
# Receiving objects: 100% (163/163), 180.22 KiB | 16.38 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# /content/stat-ood
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 87 packages in 1ms
# Installed 85 packages in 390ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + antlr4-python3-runtime==4.9.3
#  + anyio==4.12.1
#  + attrs==25.4.0
#  + certifi==2026.1.4
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + datasets==4.4.2
#  + dill==0.4.0
#  + filelock==3.20.3
#  + frozenlist==1.8.0
#  + fsspec==2025.10.0
#  + gitdb==4.0.12
#  + gitpython==3.1.46
#  + h11==0.16.0
#  + hf-xet==1.2.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==0.36.0
#  + hydra-core==1.3.2
#  + idna==3.11
#  + jinja2==3.1.6
#  + joblib==1.5.3
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + multidict==6.7.0
#  + multiprocess==0.70.18
#  + networkx==3.6.1
#  + numpy==2.4.1
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufile-cu12==1.13.1.3
#  + nvidia-curand-cu12==10.3.9.90
#  + nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.27.5
#  + nvidia-nvjitlink-cu12==12.8.93
#  + nvidia-nvshmem-cu12==3.3.20
#  + nvidia-nvtx-cu12==12.8.90
#  + omegaconf==2.3.0
#  + packaging==25.0
#  + pandas==2.3.3
#  + pillow==12.1.0
#  + platformdirs==4.5.1
#  + propcache==0.4.1
#  + protobuf==6.33.3
#  + pyarrow==22.0.0
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + python-dateutil==2.9.0.post0
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + regex==2025.11.3
#  + requests==2.32.5
#  + safetensors==0.7.0
#  + scikit-learn==1.8.0
#  + scipy==1.17.0
#  + sentry-sdk==2.49.0
#  + setuptools==80.9.0
#  + six==1.17.0
#  + smmap==5.0.2
#  + sympy==1.14.0
#  + threadpoolctl==3.6.0
#  + tokenizers==0.22.2
#  + torch==2.9.1
#  + torchaudio==2.9.1
#  + torchvision==0.24.1
#  + tqdm==4.67.1
#  + transformers==4.57.3
#  + triton==3.5.1
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + tzdata==2025.3
#  + urllib3==2.6.3
#  + wandb==0.23.1
#  + xxhash==3.6.0
#  + yarl==1.22.0

# %% [markdown]
# ## 3. Quick Test (Debug Mode)

# %%
# !uv run python main.py experiment.debug=true

# %% [markdown]
# ## 4. Standard Experiment (CLINC150 - English)

# %%
# !uv run python main.py model=base dataset=base ood_method=mahalanobis
# Out:
# [2026-01-12 07:18:55,574][__main__][INFO] - Using device: cuda
# [2026-01-12 07:18:55,574][__main__][INFO] - Initializing Data Loader...
# [2026-01-12 07:18:56,887][src.data.loader][INFO] - Loading dataset: clinc_oos
# `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'clinc_oos' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# [2026-01-12 07:18:56,887][datasets.load][ERROR] - `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'clinc_oos' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# Map: 100% 15250/15250 [00:01<00:00, 8146.58 examples/s]
# Map: 100% 3100/3100 [00:00<00:00, 9233.60 examples/s]
# Map: 100% 5500/5500 [00:00<00:00, 8538.61 examples/s]
# Filter: 100% 15250/15250 [00:00<00:00, 62042.97 examples/s]
# Filter: 100% 3100/3100 [00:00<00:00, 54424.06 examples/s]
# Filter: 100% 5500/5500 [00:00<00:00, 56357.70 examples/s]
# Filter: 100% 5500/5500 [00:00<00:00, 59894.05 examples/s]
# [2026-01-12 07:19:06,353][src.data.loader][INFO] - Train (ID) size: 15150
# [2026-01-12 07:19:06,353][src.data.loader][INFO] - Val (ID) size: 3080
# [2026-01-12 07:19:06,353][src.data.loader][INFO] - Test (ID) size: 5470
# [2026-01-12 07:19:06,353][src.data.loader][INFO] - Test (OOD) size: 30
# [2026-01-12 07:19:06,354][__main__][INFO] - Initializing Model...
# [2026-01-12 07:19:07,404][src.models.wrapper][INFO] - Initialized ModelWrapper with pooling strategy: cls
# [2026-01-12 07:19:07,405][__main__][INFO] - Initializing Trainer...
# Error executing job with overrides: ['model=base', 'dataset=base', 'ood_method=mahalanobis']
# Traceback (most recent call last):
#   File "/content/stat-ood/main.py", line 51, in main
#     trainer = Trainer(cfg, model, train_loader, val_loader, optimizer)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stat-ood/src/engine/trainer.py", line 15, in __init__
#     self.device = torch.device(cfg.experiment.device)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: Expected one of cpu, cuda, ipu, xpu, mkldnn, opengl, opencl, ideep, hip, ve, fpga, maia, xla, lazy, vulkan, mps, meta, hpu, mtia, privateuseone device type at start of device string: auto
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.

# %% [markdown]
# ## 5. Advanced Experiment (MASSIVE - Korean)

# %%
# !uv run python main.py \
    dataset=massive_ko \
    model.name="intfloat/multilingual-e5-base" \
    model.pooling="mean" \
    ood_method="energy"
