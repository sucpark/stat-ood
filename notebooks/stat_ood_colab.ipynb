# %% [markdown]
# # 📊 Stat-OOD: Google Colab Experiment
#
# Welcome to the **Stat-OOD** interactive playground. This notebook allows you to clone the repository, install dependencies using `uv`, and run OOD detection experiments directly on a free Tesla T4 GPU.

# %% [markdown]
# ## 1. Setup Environment
# We use `uv` for fast package management. This step checks out the code and installs PyTorch, HuggingFace Transformers, and other dependencies.

# %%
# !nvidia-smi
# Out:
# Mon Jan 12 06:24:26 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install -q uv
# !git clone https://github.com/sucpark/stat-ood.git
# %cd stat-ood
# !uv sync
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 86.0 MB/s eta 0:00:00:00:0100:01
# Cloning into 'stat-ood'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 136 (delta 63), reused 116 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (136/136), 171.28 KiB | 1.38 MiB/s, done.
# Resolving deltas: 100% (63/63), done.
# /content/stat-ood
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 87 packages in 2ms
# Prepared 85 packages in 1m 17s
# Installed 85 packages in 702ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + antlr4-python3-runtime==4.9.3
#  + anyio==4.12.1
#  + attrs==25.4.0
#  + certifi==2026.1.4
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + datasets==4.4.2
#  + dill==0.4.0
#  + filelock==3.20.3
#  + frozenlist==1.8.0
#  + fsspec==2025.10.0
#  + gitdb==4.0.12
#  + gitpython==3.1.46
#  + h11==0.16.0
#  + hf-xet==1.2.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==0.36.0
#  + hydra-core==1.3.2
#  + idna==3.11
#  + jinja2==3.1.6
#  + joblib==1.5.3
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + multidict==6.7.0
#  + multiprocess==0.70.18
#  + networkx==3.6.1
#  + numpy==2.4.1
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufile-cu12==1.13.1.3
#  + nvidia-curand-cu12==10.3.9.90
#  + nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.27.5
#  + nvidia-nvjitlink-cu12==12.8.93
#  + nvidia-nvshmem-cu12==3.3.20
#  + nvidia-nvtx-cu12==12.8.90
#  + omegaconf==2.3.0
#  + packaging==25.0
#  + pandas==2.3.3
#  + pillow==12.1.0
#  + platformdirs==4.5.1
#  + propcache==0.4.1
#  + protobuf==6.33.3
#  + pyarrow==22.0.0
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + python-dateutil==2.9.0.post0
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + regex==2025.11.3
#  + requests==2.32.5
#  + safetensors==0.7.0
#  + scikit-learn==1.8.0
#  + scipy==1.17.0
#  + sentry-sdk==2.49.0
#  + setuptools==80.9.0
#  + six==1.17.0
#  + smmap==5.0.2
#  + sympy==1.14.0
#  + threadpoolctl==3.6.0
#  + tokenizers==0.22.2
#  + torch==2.9.1
#  + torchaudio==2.9.1
#  + torchvision==0.24.1
#  + tqdm==4.67.1
#  + transformers==4.57.3
#  + triton==3.5.1
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + tzdata==2025.3
#  + urllib3==2.6.3
#  + wandb==0.23.1
#  + xxhash==3.6.0
#  + yarl==1.22.0

# %% [markdown]
# ## 2. Quick Verification (Debug Mode)
# Run a fast 1-epoch training cycle to verify everything is working correctly.

# %%
# !uv run python main.py experiment.debug=true
# Out:
# [2026-01-12 05:43:18,775][__main__][INFO] - Using device: cpu
# [2026-01-12 05:43:18,776][__main__][INFO] - Initializing Data Loader...
# [2026-01-12 05:43:19,440][src.data.loader][INFO] - Loading dataset: clinc_oos
# Map: 100% 15250/15250 [00:02<00:00, 5676.46 examples/s]
# Map: 100% 3100/3100 [00:00<00:00, 4142.98 examples/s]
# Map: 100% 5500/5500 [00:01<00:00, 4032.23 examples/s]
# Filter: 100% 15250/15250 [00:00<00:00, 28812.47 examples/s]
# Filter: 100% 3100/3100 [00:00<00:00, 28654.67 examples/s]
# Filter: 100% 5500/5500 [00:00<00:00, 38470.23 examples/s]
# Filter: 100% 5500/5500 [00:00<00:00, 50893.10 examples/s]
# [2026-01-12 05:43:27,749][src.data.loader][INFO] - Train (ID) size: 15150
# [2026-01-12 05:43:27,749][src.data.loader][INFO] - Val (ID) size: 3080
# [2026-01-12 05:43:27,749][src.data.loader][INFO] - Test (ID) size: 5470
# [2026-01-12 05:43:27,749][src.data.loader][INFO] - Test (OOD) size: 30
# [2026-01-12 05:43:27,750][__main__][INFO] - Initializing Model...
# [2026-01-12 05:43:29,138][src.models.wrapper][INFO] - Initialized ModelWrapper with pooling strategy: cls
# [2026-01-12 05:43:29,140][__main__][INFO] - Starting OOD Fitting...
# [2026-01-12 05:43:29,140][src.ood.calculator][INFO] - OOD Calculator Strategy: mahalanobis
# [2026-01-12 05:43:29,141][__main__][INFO] - Extracting features from Training set for OOD fitting...
# /content/stat-ood/stat-ood/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# [2026-01-12 05:43:42,341][src.ood.mahalanobis][INFO] - Fitting Mahalanobis Strategy...
# [2026-01-12 05:43:42,901][src.ood.mahalanobis][INFO] - Mahalanobis fitting complete.
# [2026-01-12 05:43:42,902][__main__][INFO] - Evaluating OOD scores on ID and OOD Test sets...
# /content/stat-ood/stat-ood/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# [2026-01-12 05:44:07,010][__main__][INFO] - OOD Results - AUROC: 0.6823, FPR@95: 0.7812
# [2026-01-12 05:44:07,010][__main__][INFO] - Creating Visualizations...
# [2026-01-12 05:44:07,013][__main__][INFO] - Pipeline finished.

# %% [markdown]
# ## 3. Run Standard Experiment (English)
# Train BERT on CLINC150 (English) and evaluate using **Mahalanobis Distance**.

# %%
# !uv run python main.py model=base dataset=ba3se ood_method=mahalanobis
# Out:
# In 'config': Could not find 'dataset/ba3se'
#
# Available options in 'dataset':
# 	base
# 	massive_ko
# Config search path:
# 	provider=hydra, path=pkg://hydra.conf
# 	provider=main, path=file:///content/stat-ood/stat-ood/configs
# 	provider=schema, path=structured://
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.

# %% [markdown]
# ## 4. Run Advanced Experiment (Korean + E5 + Energy)
# This runs the research-grade configuration:
# *   **Dataset**: MASSIVE (Korean)
# *   **Model**: E5-Multilingual (Mean Pooling)
# *   **Method**: Energy Score

# %%
# !uv run python main.py \
    dataset=massive_ko \
    model.name="intfloat/multilingual-e5-base" \
    model.pooling="mean" \
    ood_method="energy"

# %% [markdown]
# ## 5. WandB Login (Optional)
# To visualize results in Weights & Biases, run the cell below and enter your API key.

# %%
# !uv run wandb login
